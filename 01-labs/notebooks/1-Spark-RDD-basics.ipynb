# %% [markdown]
# ## Working with RDDs (ch 3)

# %% [markdown]
# You control a Spark process by means of a Spark Context. In Python, the `Spark context` is a built-in variable, already bound to the Context. When using Java (or Scala), you need to do the binding yourself

# %%
sc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: </div>
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=1048156679166715#setting/sparkui/1219-084116-d7kyzrk9/driver-2513275466051662466">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://10.139.64.6:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %% [markdown]
# you will use `sc` to ask Spark to load the content of a file into memory, for instance:

# %% [markdown]
# ## RDD: Resilient Distributed Dataset ##
#
# The basic data abstraction for all Spark programs is the RDD. Think of an RDD as an immutable, distributed collection of objects (data elements) of a certain type.
#
# Users create RDDs in two ways: by loading an external dataset, as we have just seen, or programmatically by specifying that a collection of objects, for instance a list or set, is to be processed a set of N *workers*:
#
# note that Spark 2.x now support a higher level abstraction for relational data, called **DataFrames**. if you are familiar with Python Pandas or the R language, you will recognise Spark DataFrames as a very similar abstraction for tabular data. We will look at DataFrames in details later. For now, you may  refer to this tutorial: [Spark SQL, DataFrames and Datasets Guide](https://spark.apache.org/docs/latest/sql-programming-guide.html)

# %%
# specifies the number of workers:
myData = sc.parallelize([1,2,3,5],3)
myData
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: ParallelCollectionRDD[95] at readRDDFromInputStream at PythonRDD.scala:413</div>

# %%
# distributes the content of the RDD to all available workers:

sc.parallelize(["pandas", "i like pandas"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: ParallelCollectionRDD[96] at readRDDFromInputStream at PythonRDD.scala:413</div>

# %%
#Example (3.1): create a new RDD by loading a text file using the SparkContext sc
lines = sc.textFile('/FileStore/tables/Dante_Inferno.txt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Transformations and Actions ##
#
# Spark operates on RDDs in two ways:
#
# - through **transformations**. A transformation takes an input RDD and produces a new RDD. Example: filtering an RDD
# - through **actions**. An Action takes an RDD and produces data of some other type, which typically encodes the result of some data analysis. Example: count the number of lines in a file

# %% [markdown]
# example of transformation:
#
# the myRDD.filter() function filters myRDD according to a condition. The condition is specified using a function as one of the arguments to filter(). Here is the general Python syntax for passing a `lambda function` to another function:

# %%
infernoLines = lines.filter(lambda x: "inferno" in x)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Action: a result computed from an RDD, which can be either returned to the driver program or saved to an external storage system (e.g., HDFS).  examples:

# %%
# operates on the lines RDD
lines.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: 6496</div>

# %%
# shows top k elements in the RDD 
lines.take(20)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [&#39;  LA DIVINA COMMEDIA&#39;,
#  &#39;  di Dante Alighieri&#39;,
#  &#39;&#39;,
#  &#39;&#39;,
#  &#39;&#39;,
#  &#39;&#39;,
#  &#39;&#39;,
#  &#39;  INFERNO&#39;,
#  &#39;&#39;,
#  &#39;&#39;,
#  &#39;&#39;,
#  &#39;&#39;,
#  &#39;  Inferno \x95 Canto I&#39;,
#  &#39;&#39;,
#  &#39;&#39;,
#  &#39;  Nel mezzo del cammin di nostra vita&#39;,
#  &#39;  mi ritrovai per una selva oscura,&#39;,
#  &#39;  ché la diritta via era smarrita.&#39;,
#  &#39;&#39;,
#  &#39;  Ahi quanto a dir qual era è cosa dura&#39;]</div>

# %% [markdown]
# Actions are typically performed at the end of a pipeline consisting of one or more transformations.
#
# Here is a new transformation that makes use of the `map()` higher order function:

# %%
uppercaseLines = lines.map(lambda s: s.upper())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# like filter,  `map()` is a transformation. It takes an input function (a named or a lambda function). It applies the function to each element of the input RDD to produce an output RDD

# %%
uppercaseLines
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: PythonRDD[101] at RDD at PythonRDD.scala:58</div>

# %%
uppercaseLines.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [&#39;  LA DIVINA COMMEDIA&#39;, &#39;  DI DANTE ALIGHIERI&#39;, &#39;&#39;, &#39;&#39;, &#39;&#39;]</div>

# %%
infernoLines.first()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: &#39;  né lo profondo inferno li riceve,&#39;</div>

# %% [markdown]
# note that the result of the take(n) action function is no longer an RDD! in this instance, it is a list of strings

# %% [markdown]
# note that you may concatenate the two transformations and the action into a single command using 'dot notation':

# %%
lines.filter(lambda x: "inferno" in x).map(lambda s: s.upper()).take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: [&#39;  NÉ LO PROFONDO INFERNO LI RICEVE,&#39;,
#  &#39;  VEDE QUAL LOCO D\x92INFERNO È DA ESSA;&#39;,
#  &#39;  COME TU VEDI IN QUESTO BASSO INFERNO».&#39;,
#  &#39;  COM\x92 AVESSE L\x92INFERNO A GRAN DISPITTO.&#39;,
#  &#39;  CH\x92I\x92 DISCESI QUA GIÙ NEL BASSO INFERNO,&#39;]</div>

# %% [markdown]
# or you can use the functions you have defined to perform these operations:

# %%
def upperCase(doc):
    return doc.map(lambda s: s.upper())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def filterDocForTerm(doc, term):
    return doc.filter(lambda x: term in x)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
upperCase(filterDocForTerm(lines, "inferno")).take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: [&#39;  NÉ LO PROFONDO INFERNO LI RICEVE,&#39;,
#  &#39;  VEDE QUAL LOCO D\x92INFERNO È DA ESSA;&#39;,
#  &#39;  COME TU VEDI IN QUESTO BASSO INFERNO».&#39;,
#  &#39;  COM\x92 AVESSE L\x92INFERNO A GRAN DISPITTO.&#39;,
#  &#39;  CH\x92I\x92 DISCESI QUA GIÙ NEL BASSO INFERNO,&#39;,
#  &#39;  LUOGO È IN INFERNO DETTO MALEBOLGE,&#39;,
#  &#39;  SÌ CHE \x92N INFERNO I\x92 CREDEA TORNAR ANCHE.&#39;]</div>

# %% [markdown]
# we can also explicitly define functions that we can then use in `map()`:

# %%
def removex92(s):
    return s.replace('\x92','\'')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lines.filter(lambda x: "inferno" in x).map(removex92).take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: [&#39;  né lo profondo inferno li riceve,&#39;,
#  &#34;  vede qual loco d&#39;inferno è da essa;&#34;,
#  &#39;  come tu vedi in questo basso inferno».&#39;,
#  &#34;  com&#39; avesse l&#39;inferno a gran dispitto.&#34;,
#  &#34;  ch&#39;i&#39; discesi qua giù nel basso inferno,&#34;]</div>

# %% [markdown]
# or equivalently:

# %%
lines.filter(lambda x: "inferno" in x).map(lambda s: s.replace('\x92','')).take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: [&#39;  né lo profondo inferno li riceve,&#39;,
#  &#39;  vede qual loco dinferno è da essa;&#39;,
#  &#39;  come tu vedi in questo basso inferno».&#39;,
#  &#39;  com avesse linferno a gran dispitto.&#39;,
#  &#39;  chi discesi qua giù nel basso inferno,&#39;]</div>

# %%
# other obvious action: counting the number of elements
infernoLines.count(), uppercaseLines.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: (7, 6496)</div>

# %% [markdown]
# ## Lazy evaluation:##
#
# Spark computes a pipeline in a **lazy** fashion—that is, the resulting RDD remains virtual and no computation  actually occurs until the RDD is used as input to an action.
#
# Thus, actions have the potentual to trigger an entire complex pipeline to be executed.
#
# If Spark were to load and store all the lines in the file as soon as we wrote lines = sc.textFile(...), it would waste a lot of storage space, given that we then immediately filter out many lines. Instead, once Spark sees the whole chain of transformations, it can compute just the data needed for its result. In fact, for the first() action, Spark scans the file only until it finds the first matching line; it doesn’t even read the whole file.
#
# Note that a virtual computation may be described by a graph, for instance:

# %% [markdown]
# try changing the file path below to a non-existent name like `/FileStore/tables/Dante_Inferno-XXX.txt`

# %%
lines = sc.textFile('/FileStore/tables/Dante_Inferno.txt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cleanLines = lines.map(lambda s: s.replace('\x92',''))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
upperInferno = cleanLines.filter(lambda x: "inferno" in x).map(lambda s: s.upper())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lowerAmore = cleanLines.filter(lambda x: "amore" in x).map(lambda s: s.lower())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# at this point, no computation has actually occurred. In fact the file hasn't even been opened (try and change the path to the file)

# %% [markdown]
# however when an action is performed on *at least one* of the output RDDs:  `upperInferno`, `lowerAmore`, Spark schedules the entire execution graph in a distributed fashion using the available workers, in order to produce a result:

# %%
upperInferno.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: [&#39;  NÉ LO PROFONDO INFERNO LI RICEVE,&#39;,
#  &#39;  VEDE QUAL LOCO DINFERNO È DA ESSA;&#39;,
#  &#39;  COME TU VEDI IN QUESTO BASSO INFERNO».&#39;,
#  &#39;  COM AVESSE LINFERNO A GRAN DISPITTO.&#39;,
#  &#39;  CHI DISCESI QUA GIÙ NEL BASSO INFERNO,&#39;,
#  &#39;  LUOGO È IN INFERNO DETTO MALEBOLGE,&#39;,
#  &#39;  SÌ CHE N INFERNO I CREDEA TORNAR ANCHE.&#39;]</div>

# %%
lowerAmore.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: [&#39;  vagliami l lungo studio e l grande amore&#39;,
#  &#39;  ma sapïenza, amore e virtute,&#39;,
#  &#39;  la somma sapïenza e l primo amore.&#39;,
#  &#39;  che con amore al fine combatteo.&#39;,
#  &#39;  a che e come concedette amore&#39;,
#  &#39;  del vecchio padre, né l debito amore&#39;,
#  &#39;  al padre, fuor del dritto amore, amica.&#39;]</div>

# %% [markdown]
# have you tried using the wrong filename?  at which point do you get a runtime error?

# %% [markdown]
# ## Persistence: ##
#
# A RDD that is used in multiple actions, is recomputed as part of the pipeline that leads to that action. There is therefore a potential for re-computing the same RDD multiple times.
#
# However we may tell Spark that it should reuse a partial result when we know it is safe to do so. This is done using `RDD.persist()`. For example:

# %%
# without persistence, this action causes the entire pipeline to be executed again:
upperInferno.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: 7</div>

# %%
# this ensures that the file is only loaded once and that the cleanLines RDD is kept in memory:
cleanLines.persist()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: PythonRDD[116] at RDD at PythonRDD.scala:58</div>

# %% [markdown]
# obviously there is a trade-off between the cost of reloading / recomputing and the process space needed for storing a persisted RDD

# %%
upperInferno.persist()
lowerAmore.persist()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: PythonRDD[114] at collect at &lt;command-214449445958355&gt;:1</div>

# %%
# these repeated action invocationsare now inexpensive:
upperInferno.count(), lowerAmore.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: (7, 7)</div>

# %% [markdown]
# # practice: loading and operating on a movie set #

# %% [markdown]
# We now practice these notions on a different dataset, and extend our overview of the set of transformations and actions avaiable through Spark

# %%
    inputRDD = sc.textFile('/FileStore/tables/sample_movielens_movies.txt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
inputRDD.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: [&#39;0::Movie 0::Romance|Comedy&#39;,
#  &#39;1::Movie 1::Action|Anime&#39;,
#  &#39;2::Movie 2::Romance|Thriller&#39;,
#  &#39;3::Movie 3::Action|Romance&#39;,
#  &#39;4::Movie 4::Anime|Comedy&#39;]</div>

# %% [markdown]
# Examples of **transformations**:

# %%
thrillerRDD = inputRDD.filter(lambda x: "Thriller" in x)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
comedyRDD = inputRDD.filter(lambda x: "Comedy" in x)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# you can take the **union** of two RDDs:

# %%
whatILikeRDD = thrillerRDD.union(comedyRDD)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# *Actions* - printing out the first 10 lines of each movie category

# %%
thrillerRDD.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: [&#39;2::Movie 2::Romance|Thriller&#39;,
#  &#39;9::Movie 9::Anime|Thriller&#39;,
#  &#39;13::Movie 13::Thriller|Action&#39;,
#  &#39;15::Movie 15::Comedy|Thriller&#39;,
#  &#39;17::Movie 17::Thriller|Action&#39;]</div>

# %%
comedyRDD.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: [&#39;0::Movie 0::Romance|Comedy&#39;,
#  &#39;4::Movie 4::Anime|Comedy&#39;,
#  &#39;6::Movie 6::Action|Comedy&#39;,
#  &#39;7::Movie 7::Anime|Comedy&#39;,
#  &#39;8::Movie 8::Comedy|Action&#39;,
#  &#39;12::Movie 12::Anime|Comedy&#39;,
#  &#39;14::Movie 14::Anime|Comedy&#39;,
#  &#39;15::Movie 15::Comedy|Thriller&#39;,
#  &#39;18::Movie 18::Action|Comedy&#39;,
#  &#39;23::Movie 23::Comedy|Comedy&#39;]</div>

# %%
whatILikeRDD.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: [&#39;2::Movie 2::Romance|Thriller&#39;,
#  &#39;9::Movie 9::Anime|Thriller&#39;,
#  &#39;13::Movie 13::Thriller|Action&#39;,
#  &#39;15::Movie 15::Comedy|Thriller&#39;,
#  &#39;17::Movie 17::Thriller|Action&#39;]</div>

# %% [markdown]
# note: the `collect()` function retrieves the entire RDD.
#
# *Note that this forces Spark to execute the entire pipeline* so not to be used on large datasets unless you know that processing requires the entire dataset to be consumed outside of the RDD framework.

# %%
whatILikeRDD.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: 73</div>

# %% [markdown]
# **Passing functions to Spark** (ch 3 pg. 30). we have seen this before...

# %%
def isThriller(s): 
    return "Thriller" in s
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
thrillers = whatILikeRDD.filter(isThriller)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
thrillers.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: [&#39;2::Movie 2::Romance|Thriller&#39;,
#  &#39;9::Movie 9::Anime|Thriller&#39;,
#  &#39;13::Movie 13::Thriller|Action&#39;,
#  &#39;15::Movie 15::Comedy|Thriller&#39;,
#  &#39;17::Movie 17::Thriller|Action&#39;]</div>
