# %%
uuRDD = sc.textFile('/FileStore/tables/uu_noheader.txt')


uuRDD.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [&#39;wear-purple-for-jia-2018,foomooboo,Ed_Miliband,1&#39;,
#  &#39;dry-january-2018,kellyld77,DrinkTg,1&#39;,
#  &#39;mnd-awareness-month-2018,charitybegin3,MNDAEastSussex,1&#39;,
#  &#39;ocd-awareness-week-2018,janinak_artwork,lwbean,1&#39;,
#  &#39;elf-day,ramsdensburnco,JodieRamsdens,1&#39;]</div>

# %%
## tokenise the string
uu_tokens = uuRDD.map(lambda x: x.split(','))

uu_tokens.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: [[&#39;wear-purple-for-jia-2018&#39;, &#39;foomooboo&#39;, &#39;Ed_Miliband&#39;, &#39;1&#39;],
#  [&#39;dry-january-2018&#39;, &#39;kellyld77&#39;, &#39;DrinkTg&#39;, &#39;1&#39;],
#  [&#39;mnd-awareness-month-2018&#39;, &#39;charitybegin3&#39;, &#39;MNDAEastSussex&#39;, &#39;1&#39;],
#  [&#39;ocd-awareness-week-2018&#39;, &#39;janinak_artwork&#39;, &#39;lwbean&#39;, &#39;1&#39;],
#  [&#39;elf-day&#39;, &#39;ramsdensburnco&#39;, &#39;JodieRamsdens&#39;, &#39;1&#39;]]</div>

# %% [markdown]
# find the top 3 contexts that have the highest number of records

# %%
## all we need is the first element of each list, and we just use the "wordCount" pattern to count the number of occurrences

contexts = uu_tokens.map(lambda l: l[0])

contexts.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: [&#39;wear-purple-for-jia-2018&#39;,
#  &#39;dry-january-2018&#39;,
#  &#39;mnd-awareness-month-2018&#39;,
#  &#39;ocd-awareness-week-2018&#39;,
#  &#39;elf-day&#39;]</div>

# %%
## this is just wordcount:

context_occurrences = contexts.map(lambda s: (s,1)).reduceByKey(lambda x,y: x+y)

top_5_contexts = context_occurrences.sortBy(lambda x: x[1], ascending=False).map(lambda x: x[0]).take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
top_5_contexts
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: [&#39;16-days-of-action-2018&#39;,
#  &#39;elf-day&#39;,
#  &#39;stress-awareness-day&#39;,
#  &#39;mental-health-awareness-week-2018&#39;,
#  &#39;ocd-awareness-week-2018&#39;]</div>

# %% [markdown]
# task 2: for the top context, calculate the total weight associated with each outgoing edge for that context
#
# ex
# `'wear-purple-for-jia-2018,foomooboo,Ed_Miliband,1',
#  'dry-january-2018,kellyld77,DrinkTg,1',`
#
#  the edges are `foomooboo --> Ed_Miliband` and `kellyld77 --> DrinkTg`

# %%
## the idea is to use a pair (from,to) to represent an edge. Thus we use this pair as the key in the key value pair
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
edge_weights = uu_tokens.filter(lambda l: l[0] == '16-days-of-action-2018').map(lambda l: ((l[1],l[2]), l[3]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
edge_weights.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: [((&#39;ramsdensburnco&#39;, &#39;JodieRamsdens&#39;), &#39;1&#39;),
#  ((&#39;tweetyouuk&#39;, &#39;RinginglowArrow&#39;), &#39;1&#39;),
#  ((&#39;meisafairy&#39;, &#39;thesovrangroup&#39;), &#39;1&#39;),
#  ((&#39;bouncytits1&#39;, &#39;sophiemk_escort&#39;), &#39;1&#39;),
#  ((&#39;jwemeryltd&#39;, &#39;RCHhomes&#39;), &#39;1&#39;)]</div>

# %%
total_edge_weights = edge_weights.reduceByKey(lambda x,y : x+y).sortBy(lambda x: x[1])

total_edge_weights.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[43]
#39;, &#39;thesovrangroup&#39;), &#39;1&#39;),
#  ((&#39;devansnhs&#39;, &#39;heartofacutemed&#39;), &#39;1&#39;),
#  ((&#39;dianepittard&#39;, &#39;HHFTnhs&#39;), &#39;1&#39;),
#  ((&#39;priyankasouthin&#39;, &#39;PCsDRAG0N&#39;), &#39;1&#39;),
#  ((&#39;ulsu_welfare&#39;, &#39;AlzheimersLincs&#39;), &#39;1&#39;),
#  ((&#39;nhshullccg&#39;, &#39;michaelfoers&#39;), &#39;1&#39;),
#  ((&#39;wesaynisa&#39;, &#39;NisaRetail&#39;), &#39;1&#39;),
#  ((&#39;greatcareco&#39;, &#39;alzheimerssoc&#39;), &#39;1&#39;),
#  ((&#39;trusatcgal&#39;, &#39;ashover_team&#39;), &#39;1&#39;),
#  ((&#39;heratywellsymt&#39;, &#39;YMT_Chris&#39;), &#39;1&#39;),
#  ((&#39;zer0t0l0rance&#39;, &#39;LitterboxComics&#39;), &#39;1&#39;),
#  ((&#39;boxtoox&#39;, &#39;VoucherLive&#39;), &#39;1&#39;),
#  ((&#39;hunterlouise&#39;, &#39;nwater_care&#39;), &#39;1&#39;),
#  ((&#39;priyankac_fan0&#39;, &#39;PCsDRAG0N&#39;), &#39;1&#39;),
#  ((&#39;ramsdensburnco&#39;, &#39;JodieRamsdens&#39;), &#39;1&#39;),
#  ((&#39;meisafairy&#39;, &#39;thesovrangroup&#39;), &#39;1&#39;),
#  ((&#39;bouncytits1&#39;, &#39;sophiemk_escort&#39;), &#39;1&#39;),
#  ((&#39;jwemeryltd&#39;, &#39;RCHhomes&#39;), &#39;1&#39;),
#  ((&#39;jaybelevee&#39;, &#39;thesovrangroup&#39;), &#39;1&#39;),
#  ((&#39;twittmanageruk&#39;, &#39;RinginglowArrow&#39;), &#39;1&#39;),
#  ((&#39;alzsocnwengland&#39;, &#39;crystallegal&#39;), &#39;1&#39;),
#  ((&#39;cnlyld&#39;, &#39;PCsDRAG0N&#39;), &#39;1&#39;),
#  ((&#39;sharon_tweeter&#39;, &#39;thesovrangroup&#39;), &#39;1&#39;),
#  ((&#39;hygieiagroupltd&#39;, &#39;TheOaks28&#39;), &#39;1&#39;),
#  ((&#39;andersonjuliee&#39;, &#39;KarenLeeDWP&#39;), &#39;1&#39;),
#  ((&#39;beliver58558797&#39;, &#39;PCsDRAG0N&#39;), &#39;1&#39;),
#  ((&#39;essutility&#39;, &#39;TheOaks28&#39;), &#39;1&#39;),
#  ((&#39;mjbfoodservice&#39;, &#39;NotaroCare&#39;), &#39;1&#39;),
#  ((&#39;ybreevaart67_63&#39;, &#39;NisaRetail&#39;), &#39;1&#39;),
#  ((&#39;alisonlrdash&#39;, &#39;rdash_nhs&#39;), &#39;1&#39;),
#  ((&#39;kaymass18815646&#39;, &#39;jk_janetkaye&#39;), &#39;1&#39;),
#  ((&#39;coolpenguin2017&#39;, &#39;thesovrangroup&#39;), &#39;1&#39;),
#  ((&#39;foolforbutera&#39;, &#39;VoucherLive&#39;), &#39;1&#39;),
#  ((&#39;ectstaff&#39;, &#39;EastCheshireNH1&#39;), &#39;1&#39;),
#  ((&#39;rbatsocialmedia&#39;, &#39;RinginglowArrow&#39;), &#39;1&#39;),
#  ((&#39;fifthdumbledore&#39;, &#39;PCsDRAG0N&#39;), &#39;1&#39;),
#  ((&#39;carolinearm&#39;, &#39;Girlingslawyers&#39;), &#39;1&#39;),
#  ((&#39;roshnip77&#39;, &#39;thesovrangroup&#39;), &#39;1&#39;),
#  ((&#39;jessthompkemp&#39;, &#39

# %% [markdown]
# we can achieve the same result more easily, using the DataFrame API:

# %%
from pyspark.sql.types import IntegerType

## load the uu.txt raw file as RDD

uuDF = spark.read.csv('/FileStore/tables/uu.csv', header=True)

uuDF = uuDF.withColumn("weight",uuDF.weight.cast(IntegerType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# top 5 contexts:
uuDF.groupBy(uuDF.context).count().sort('count', ascending = False).take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[77]: [Row(context=&#39;16-days-of-action-2018&#39;, count=240),
#  Row(context=&#39;elf-day&#39;, count=188),
#  Row(context=&#39;stress-awareness-day&#39;, count=173),
#  Row(context=&#39;mental-health-awareness-week-2018&#39;, count=172),
#  Row(context=&#39;ocd-awareness-week-2018&#39;, count=171)]</div>

# %% [markdown]
# task 2: for the top context, calculate the total weight associated with each edge for that context
#
# using DataFrames

# %%
uuDF.filter(uuDF.context == '16-days-of-action-2018').groupby(['from', 'to']).sum('weight').take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[78]: [Row(from=&#39;ckatrib&#39;, to=&#39;lav__k&#39;, sum(weight)=1),
#  Row(from=&#39;guilhermebigar1&#39;, to=&#39;UN_Women&#39;, sum(weight)=1),
#  Row(from=&#39;gomathiraghava4&#39;, to=&#39;PlanGlobal&#39;, sum(weight)=2),
#  Row(from=&#39;nirwind&#39;, to=&#39;saraloal&#39;, sum(weight)=1),
#  Row(from=&#39;jennygeebee&#39;, to=&#39;lynseyjfenners&#39;, sum(weight)=1)]</div>

# %% [markdown]
# finally, we can achieve the same goal using the SQL API

# %%
uuDF.createOrReplaceTempView('uu')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## top contexts:
spark.sql("SELECT context, count(context) as records_per_context FROM uu group by context order by records_per_context desc").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------------------+
#              context|records_per_context|
# +--------------------+-------------------+
# 16-days-of-action...|                240|
#              elf-day|                188|
# stress-awareness-day|                173|
# mental-health-awa...|                172|
# ocd-awareness-wee...|                171|
# nutrition-and-hyd...|                168|
# time-to-talk-day-...|                165|
#  jeans-for-genes-day|                163|
# mens-health-week-...|                160|
# national-dyslexia...|                158|
# eating-disorder-a...|                158|
#     carers-week-2018|                156|
# national-dementia...|                155|
# brain-awareness-w...|                155|
# rare-disease-day-...|                147|
# wear-purple-for-j...|                141|
# dementia-action-w...|                140|
# brain-injury-week...|                138|
# epilepsy-awarenes...|                138|
# ovarian-cancer-aw...|                135|
# +--------------------+-------------------+
# only showing top 20 rows
#
# </div>

# %%
## total weights for a given context:
spark.sql("SELECT uu.from, uu.to, sum(uu.weight) as tot_weight FROM uu group by uu.from, uu.to").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------+---------------+----------+
#            from|             to|tot_weight|
# +---------------+---------------+----------+
#  avrildrummond1|HappyLittleHugh|         1|
#  uommskresearch|     CapsieNair|         1|
#     sleepycat65|  alzheimerssoc|         1|
#   heatherbowes7|  SterlingJoy94|         1|
#     copter_fstr|         lwbean|         1|
#   sucksniallers|   MrsAnneTwist|         1|
#   mynameisandyj|    YBProgramme|         1|
#     mcapn_co_uk|   ACT_4_CHANGE|         1|
#         ckatrib|         lav__k|         1|
#   lottie_newitt|        The_RHS|         1|
#     roseobyrne3|        NPA1921|         1|
#    maineoptions|    MedicareGov|         1|
#     sianmorganb|      Catrin193|         1|
#       aminulacj|           ESRC|         1|
#   mynameisandyj|     gtscollins|         1|
# alsassistivetec|Helping_HandsUK|         1|
#    carongregory|    EarleyTracy|         1|
#       samjc1976|VersusArthritis|         1|
#         rc4b_ev|  JamesMelville|         1|
#     breathe2025|smokefreelifeOx|         1|
# +---------------+---------------+----------+
# only showing top 20 rows
#
# </div>
